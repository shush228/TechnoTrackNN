# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

from typing import Tuple, List, Type, Dict, Any

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
class Perceptron(torch.nn.Module):
    
    def __init__(self, 
                 input_resolution: Tuple[int, int] = (28, 28),
                 input_channels: int = 1, 
                 hidden_layer_features: List[int] = [256, 256, 256],
                 activation: Type[torch.nn.Module] = torch.nn.SELU,
                 num_classes: int = 10):

        super().__init__()


        self.input_resolution = input_resolution
        self.input_channels = input_channels
        self.hidden_layer_features = hidden_layer_features
        self.activation = activation
        self.num_classes = num_classes
        

        self.layer1 = torch.nn.Linear(self.input_resolution[0] * self.input_resolution[1], 256)
        self.layer2 = torch.nn.Linear(256, self.num_classes)
        
    def forward(self, x):
      
        selu = self.activation()
        x = x.to(device)

        x = self.layer1(x)
        x = selu(torch.tensor(x))
        x = self.layer2(x)

        log_softmax = torch.nn.functional.log_softmax(x, dim = 1)

        return log_softmax

# %%
model = Perceptron()
print(model)
print('Total number of trainable parameters', 
      sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# Perceptron(
#   (layer1): Linear(in_features=784, out_features=256, bias=True)
#   (layer2): Linear(in_features=256, out_features=10, bias=True)
# )
# Total number of trainable parameters 203530

# %%
train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.1307,), (0.3081,))
    
])

val_transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.1307,), (0.3081,))
])

# %%
train_dataset = torchvision.datasets.MNIST(root='./mnist', 
                                           train=True, 
                                           download=True,
                                           transform=train_transforms)

val_dataset = torchvision.datasets.MNIST(root='./mnist', 
                                         train=False, 
                                         download=True, 
                                         transform=val_transforms)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Processing...
# Done!
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
data = list()
for i in range(len(train_dataset)):
    data.append(train_dataset[i][0].numpy())
data = np.array(data)
print('std:', data.std())
print('mean:', data.mean())
# Out:
# std: 1.0000249
# mean: -0.00012829367

# %%
del data

# %%
indices = np.random.randint(0, len(train_dataset), size=256)

fig, axes = plt.subplots(nrows=16, ncols=16, figsize=(32, 32))
for i, row in enumerate(axes):
    for j, ax in enumerate(row):
        sample_index = indices[i*16+j]
        sample, label = train_dataset[sample_index]
        ax.imshow(sample.cpu().numpy().transpose(1, 2, 0).squeeze())
        ax.set_title(label)

# %%
def train_single_epoch(model: torch.nn.Module,
                       optimizer: torch.optim.Optimizer, 
                       loss_function: torch.nn.Module, 
                       data_loader: torch.utils.data.DataLoader):
    
    model.train()
    loss_sum = 0

    for data in data_loader:
        x, y = data
        x = x.view(-1, 784)
        x, y = x.to(device), y.to(device)

        model.zero_grad()
        hyp = model(x)
        loss = loss_function(hyp, y)
        loss.backward()
        loss_sum += loss
        
        optimizer.step()

    
    return loss_sum / len(data_loader.dataset)

# %%
def validate_single_epoch(model: torch.nn.Module,
                          loss_function: torch.nn.Module, 
                          data_loader: torch.utils.data.DataLoader):
    model.eval()
    loss_sum = 0
    accuracy = 0

    for data in data_loader:
        x, y = data
        x = x.view(-1, 784)
        x, y = x.to(device), y.to(device)

        hyp = model(x)
        loss = loss_function(hyp, y)
        loss_sum += loss

        y_pred = hyp.argmax(dim = 1, keepdim = True).to(device)
        accuracy += y_pred.eq(y.view_as(y_pred)).sum().item()

    loss_avr = loss_sum / len(data_loader.dataset)
    accuracy_avr = 100 * accuracy / len(data_loader.dataset)
    
    return {'loss' : loss_avr.item(), 'accuracy' : accuracy_avr}

# %%
def train_model(model: torch.nn.Module, 
                train_dataset: torch.utils.data.Dataset,
                val_dataset: torch.utils.data.Dataset,
                loss_function: torch.nn.Module = torch.nn.CrossEntropyLoss(),
                optimizer_class: Type[torch.optim.Optimizer] = torch.optim,
                optimizer_params: Dict = {},
                initial_lr = 0.01,
                lr_scheduler_class: Any = torch.optim.lr_scheduler.ReduceLROnPlateau,
                lr_scheduler_params: Dict = {},
                batch_size = 1024,
                max_epochs = 1000,
                early_stopping_patience = 20):
  
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=initial_lr, **optimizer_params)
    lr_scheduler = lr_scheduler_class(optimizer, **lr_scheduler_params)
    
    train_loader = torch.utils.data.DataLoader(train_dataset, shuffle=True, batch_size=batch_size)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size)

    best_val_loss = None
    best_epoch = None
    

    for epoch in range(max_epochs):
        
        print(f'Epoch {epoch}')
        train_single_epoch(model, optimizer, loss_function, train_loader)
        val_metrics = validate_single_epoch(model, loss_function, val_loader)
        print(f'Validation metrics: \n{val_metrics}')

        lr_scheduler.step(val_metrics['loss'])
        
        if best_val_loss is None or best_val_loss > val_metrics['loss']:
            print(f'Best model yet, saving')
            best_val_loss = val_metrics['loss']
            best_epoch = epoch
            torch.save(model, './best_model.pth')
            
        if epoch - best_epoch > early_stopping_patience:
            print('Early stopping triggered')
            return

# %%
train_model(model, 
            train_dataset=train_dataset, 
            val_dataset=val_dataset, 
            loss_function=torch.nn.CrossEntropyLoss(), 
            initial_lr = 0.01)
# Out:
# Epoch 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Validation metrics:
# {'loss': 0.0003454984980635345, 'accuracy': 89.97}
# Best model yet, saving
# Epoch 1
# Validation metrics:
# {'loss': 0.0003172463912051171, 'accuracy': 90.78}
# Best model yet, saving
# Epoch 2
# Validation metrics:
# {'loss': 0.00030819844687357545, 'accuracy': 90.86}
# Best model yet, saving
# Epoch 3
# Validation metrics:
# {'loss': 0.0002979056735057384, 'accuracy': 91.54}
# Best model yet, saving
# Epoch 4
# Validation metrics:
# {'loss': 0.00029609721968881786, 'accuracy': 91.47}
# Best model yet, saving
# Epoch 5
# Validation metrics:
# {'loss': 0.00029289087979122996, 'accuracy': 91.52}
# Best model yet, saving
# Epoch 6
# Validation metrics:
# {'loss': 0.000296451966278255, 'accuracy': 91.42}
# Epoch 7
# Validation metrics:
# {'loss': 0.00028735125670209527, 'accuracy': 91.75}
# Best model yet, saving
# Epoch 8
# Validation metrics:
# {'loss': 0.0002865743590518832, 'accuracy': 91.74}
# Best model yet, saving
# Epoch 9
# Validation metrics:
# {'loss': 0.0002887760929297656, 'accuracy': 91.54}
# Epoch 10
# Validation metrics:
# {'loss': 0.0002869880700018257, 'accuracy': 91.51}
# Epoch 11
# Validation metrics:
# {'loss': 0.00028195983031764627, 'accuracy': 91.86}
# Best model yet, saving
# Epoch 12
# Validation metrics:
# {'loss': 0.0002838079526554793, 'accuracy': 91.81}
# Epoch 13
# Validation metrics:
# {'loss': 0.00028593663591891527, 'accuracy': 91.68}
# Epoch 14
# Validation metrics:
# {'loss': 0.00028087556711398065, 'accuracy': 91.92}
# Best model yet, saving
# Epoch 15
# Validation metrics:
# {'loss': 0.0002836699422914535, 'accuracy': 91.84}
# Epoch 16
# Validation metrics:
# {'loss': 0.00028339220443740487, 'accuracy': 91.67}
# Epoch 17
# Validation metrics:
# {'loss': 0.0002819221990648657, 'accuracy': 91.78}
# Epoch 18
# Validation metrics:
# {'loss': 0.00028294097865000367, 'accuracy': 91.6}
# Epoch 19
# Validation metrics:
# {'loss': 0.0002780982758849859, 'accuracy': 91.95}
# Best model yet, saving
# Epoch 20
# Validation metrics:
# {'loss': 0.000277425890089944, 'accuracy': 91.99}
# Best model yet, saving
# Epoch 21
# Validation metrics:
# {'loss': 0.000281882646959275, 'accuracy': 91.7}
# Epoch 22
# Validation metrics:
# {'loss': 0.0002825017727445811, 'accuracy': 91.83}
# Epoch 23
# Validation metrics:
# {'loss': 0.0002820601512212306, 'accuracy': 91.92}
# Epoch 24
# Validation metrics:
# {'loss': 0.00028070033295080066, 'accuracy': 91.83}
# Epoch 25
# Validation metrics:
# {'loss': 0.0002832032914739102, 'accuracy': 91.81}
# Epoch 26
# Validation metrics:
# {'loss': 0.00027932546800002456, 'accuracy': 91.88}
# Epoch 27
# Validation metrics:
# {'loss': 0.0002809519355650991, 'accuracy': 91.71}
# Epoch 28
# Validation metrics:
# {'loss': 0.00028040717006661, 'accuracy': 92.03}
# Epoch 29
# Validation metrics:
# {'loss': 0.00028445885982364416, 'accuracy': 91.65}
# Epoch 30
# Validation metrics:
# {'loss': 0.00028239417588338256, 'accuracy': 91.84}
# Epoch 31
# Validation metrics:
# {'loss': 0.00028319176635704935, 'accuracy': 91.81}
# Epoch 32
# Validation metrics:
# {'loss': 0.00027492622029967606, 'accuracy': 91.96}
# Best model yet, saving
# Epoch 33
# Validation metrics:
# {'loss': 0.00027547762147150934, 'accuracy': 92.06}
# Epoch 34
# Validation metrics:
# {'loss': 0.0002756084722932428, 'accuracy': 92.06}
# Epoch 35
# Validation metrics:
# {'loss': 0.0002746318350546062, 'accuracy': 92.05}
# Best model yet, saving
# Epoch 36
# Validation metrics:
# {'loss': 0.0002752726140897721, 'accuracy': 92.1}
# Epoch 37
# Validation metrics:
# {'loss': 0.00027510750805959105, 'accuracy': 92.02}
# Epoch 38
# Validation metrics:
# {'loss': 0.0002755192690528929, 'accuracy': 92.01}
# Epoch 39
# Validation metrics:
# {'loss': 0.0002752116706687957, 'accuracy': 92.0}
# Epoch 40
# Validation metrics:
# {'loss': 0.00027526170015335083, 'accuracy': 92.12}
# Epoch 41
# Validation metrics:
# {'loss': 0.0002753273583948612, 'accuracy': 92.08}
# Epoch 42
# Validation metrics:
# {'loss': 0.00027537738787941635, 'accuracy': 92.07}
# Epoch 43
# Validation metrics:
# {'loss': 0.0002743803197517991, 'accuracy': 92.15}
# Best model yet, saving
# Epoch 44
# Validation metrics:
# {'loss': 0.0002743992081377655, 'accuracy': 92.05}
# Epoch 45
# Validation metrics:
# {'loss': 0.0002753299195319414, 'accuracy': 92.01}
# Epoch 46
# Validation metrics:
# {'loss': 0.00027502511511556804, 'accuracy': 92.04}
# Epoch 47
# Validation metrics:
# {'loss': 0.0002752409491222352, 'accuracy': 92.09}
# Epoch 48
# Validation metrics:
# {'loss': 0.00027510072686709464, 'accuracy': 92.11}
# Epoch 49
# Validation metrics:
# {'loss': 0.0002748663246165961, 'accuracy': 92.07}
# Epoch 50
# Validation metrics:
# {'loss': 0.00027502403827384114, 'accuracy': 92.16}
# Epoch 51
# Validation metrics:
# {'loss': 0.0002740691998042166, 'accuracy': 92.13}
# Best model yet, saving
# Epoch 52
# Validation metrics:
# {'loss': 0.0002740366035141051, 'accuracy': 92.07}
# Best model yet, saving
# Epoch 53
# Validation metrics:
# {'loss': 0.000274522666586563, 'accuracy': 92.06}
# Epoch 54
# Validation metrics:
# {'loss': 0.0002743138466030359, 'accuracy': 92.01}
# Epoch 55
# Validation metrics:
# {'loss': 0.00027430287445895374, 'accuracy': 92.1}
# Epoch 56
# Validation metrics:
# {'loss': 0.0002745728997979313, 'accuracy': 92.07}
# Epoch 57
# Validation metrics:
# {'loss': 0.00027413025964051485, 'accuracy': 92.07}
# Epoch 58
# Validation metrics:
# {'loss': 0.0002746360842138529, 'accuracy': 92.1}
# Epoch 59
# Validation metrics:
# {'loss': 0.0002752756408881396, 'accuracy': 92.08}
# Epoch 60
# Validation metrics:
# {'loss': 0.00027417924138717353, 'accuracy': 92.11}
# Epoch 61
# Validation metrics:
# {'loss': 0.00027454932569526136, 'accuracy': 92.15}
# Epoch 62
# Validation metrics:
# {'loss': 0.0002749866689555347, 'accuracy': 92.1}
# Epoch 63
# Validation metrics:
# {'loss': 0.00027480695280246437, 'accuracy': 92.11}
# Epoch 64
# Validation metrics:
# {'loss': 0.00027456090901978314, 'accuracy': 92.08}
# Epoch 65
# Validation metrics:
# {'loss': 0.0002744495577644557, 'accuracy': 92.1}
# Epoch 66
# Validation metrics:
# {'loss': 0.00027438686811365187, 'accuracy': 92.12}
# Epoch 67
# Validation metrics:
# {'loss': 0.00027435674564912915, 'accuracy': 92.1}
# Epoch 68
# Validation metrics:
# {'loss': 0.00027435037191025913, 'accuracy': 92.09}
# Epoch 69
# Validation metrics:
# {'loss': 0.00027437511016614735, 'accuracy': 92.09}
# Epoch 70
# Validation metrics:
# {'loss': 0.00027438325923867524, 'accuracy': 92.08}
# Epoch 71
# Validation metrics:
# {'loss': 0.000274276128038764, 'accuracy': 92.11}
# Epoch 72
# Validation metrics:
# {'loss': 0.0002742991200648248, 'accuracy': 92.11}
# Epoch 73
# Validation metrics:
# {'loss': 0.00027433590730652213, 'accuracy': 92.1}
# Early stopping triggered

# %%
class Perceptron1(torch.nn.Module):
    
    def __init__(self, 
                 input_resolution: Tuple[int, int] = (28, 28),
                 input_channels: int = 1, 
                 hidden_layer_features: List[int] = [256, 256, 256],
                 activation: Type[torch.nn.Module] = torch.nn.SELU,
                 num_classes: int = 10):

        super().__init__()


        self.input_resolution = input_resolution
        self.input_channels = input_channels
        self.hidden_layer_features = hidden_layer_features
        self.activation = activation
        self.num_classes = num_classes
        

        self.layer1 = torch.nn.Linear(self.input_resolution[0] * self.input_resolution[1], 256)
        self.layer2 = torch.nn.Linear(256, 256)
        self.layer3 = torch.nn.Linear(256, self.num_classes)
        
    def forward(self, x):
      
        selu = self.activation()
        x = x.to(device)

        x = self.layer1(x)
        x = selu(torch.tensor(x))
        x = self.layer2(x)
        x = selu(torch.tensor(x))
        x = self.layer3(x)

        log_softmax = torch.nn.functional.log_softmax(x, dim = 1)

        return log_softmax

# %%
model1 = Perceptron1()

# %%
train_model(model1, 
            train_dataset=train_dataset, 
            val_dataset=val_dataset, 
            loss_function=torch.nn.CrossEntropyLoss(), 
            initial_lr = 0.01)
# Out:
# Epoch 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Validation metrics:
# {'loss': 0.00040263126720674336, 'accuracy': 88.42}
# Best model yet, saving
# Epoch 1
# Validation metrics:
# {'loss': 0.00036191169056110084, 'accuracy': 89.78}
# Best model yet, saving
# Epoch 2
# Validation metrics:
# {'loss': 0.0003381748974788934, 'accuracy': 90.28}
# Best model yet, saving
# Epoch 3
# Validation metrics:
# {'loss': 0.00032759507303126156, 'accuracy': 90.61}
# Best model yet, saving
# Epoch 4
# Validation metrics:
# {'loss': 0.00032015927718020976, 'accuracy': 90.92}
# Best model yet, saving
# Epoch 5
# Validation metrics:
# {'loss': 0.0003173212462570518, 'accuracy': 91.01}
# Best model yet, saving
# Epoch 6
# Validation metrics:
# {'loss': 0.0003135223814751953, 'accuracy': 91.19}
# Best model yet, saving
# Epoch 7
# Validation metrics:
# {'loss': 0.00031133877928368747, 'accuracy': 91.08}
# Best model yet, saving
# Epoch 8
# Validation metrics:
# {'loss': 0.00030668280669488013, 'accuracy': 91.12}
# Best model yet, saving
# Epoch 9
# Validation metrics:
# {'loss': 0.00030519370920956135, 'accuracy': 91.09}
# Best model yet, saving
# Epoch 10
# Validation metrics:
# {'loss': 0.0003006350016221404, 'accuracy': 91.29}
# Best model yet, saving
# Epoch 11
# Validation metrics:
# {'loss': 0.00029807433020323515, 'accuracy': 91.34}
# Best model yet, saving
# Epoch 12
# Validation metrics:
# {'loss': 0.0002970804926007986, 'accuracy': 91.2}
# Best model yet, saving
# Epoch 13
# Validation metrics:
# {'loss': 0.000298179016681388, 'accuracy': 91.59}
# Epoch 14
# Validation metrics:
# {'loss': 0.0002961235586553812, 'accuracy': 91.38}
# Best model yet, saving
# Epoch 15
# Validation metrics:
# {'loss': 0.0002943135623354465, 'accuracy': 91.49}
# Best model yet, saving
# Epoch 16
# Validation metrics:
# {'loss': 0.0002911808842327446, 'accuracy': 91.45}
# Best model yet, saving
# Epoch 17
# Validation metrics:
# {'loss': 0.00029266043566167355, 'accuracy': 91.34}
# Epoch 18
# Validation metrics:
# {'loss': 0.000289140414679423, 'accuracy': 91.6}
# Best model yet, saving
# Epoch 19
# Validation metrics:
# {'loss': 0.00028987310361117125, 'accuracy': 91.61}
# Epoch 20
# Validation metrics:
# {'loss': 0.0002961141581181437, 'accuracy': 91.53}
# Epoch 21
# Validation metrics:
# {'loss': 0.00029233688837848604, 'accuracy': 91.45}
# Epoch 22
# Validation metrics:
# {'loss': 0.0002859024389181286, 'accuracy': 91.51}
# Best model yet, saving
# Epoch 23
# Validation metrics:
# {'loss': 0.0002863638801500201, 'accuracy': 91.81}
# Epoch 24
# Validation metrics:
# {'loss': 0.00028627621941268444, 'accuracy': 91.58}
# Epoch 25
# Validation metrics:
# {'loss': 0.0002882779808714986, 'accuracy': 91.65}
# Epoch 26
# Validation metrics:
# {'loss': 0.0002848842996172607, 'accuracy': 91.68}
# Best model yet, saving
# Epoch 27
# Validation metrics:
# {'loss': 0.0002883518172893673, 'accuracy': 91.69}
# Epoch 28
# Validation metrics:
# {'loss': 0.00028248943272046745, 'accuracy': 91.75}
# Best model yet, saving
# Epoch 29
# Validation metrics:
# {'loss': 0.0002837937499862164, 'accuracy': 91.68}
# Epoch 30
# Validation metrics:
# {'loss': 0.00027880322886630893, 'accuracy': 91.87}
# Best model yet, saving
# Epoch 31
# Validation metrics:
# {'loss': 0.00028152414597570896, 'accuracy': 91.78}
# Epoch 32
# Validation metrics:
# {'loss': 0.00028435123385861516, 'accuracy': 91.66}
# Epoch 33
# Validation metrics:
# {'loss': 0.0002817206841427833, 'accuracy': 91.79}
# Epoch 34
# Validation metrics:
# {'loss': 0.0002798953210003674, 'accuracy': 91.75}
# Epoch 35
# Validation metrics:
# {'loss': 0.00027998670702800155, 'accuracy': 91.76}
# Epoch 36
# Validation metrics:
# {'loss': 0.00028294773073866963, 'accuracy': 91.86}
# Epoch 37
# Validation metrics:
# {'loss': 0.0002774823224171996, 'accuracy': 92.05}
# Best model yet, saving
# Epoch 38
# Validation metrics:
# {'loss': 0.00027814062195830047, 'accuracy': 91.9}
# Epoch 39
# Validation metrics:
# {'loss': 0.0002800579823087901, 'accuracy': 91.9}
# Epoch 40
# Validation metrics:
# {'loss': 0.0002787421690300107, 'accuracy': 91.71}
# Epoch 41
# Validation metrics:
# {'loss': 0.0002787220000755042, 'accuracy': 91.72}
# Epoch 42
# Validation metrics:
# {'loss': 0.00027750531444326043, 'accuracy': 91.79}
# Epoch 43
# Validation metrics:
# {'loss': 0.0002790154831018299, 'accuracy': 92.03}
# Epoch 44
# Validation metrics:
# {'loss': 0.00027279407368041575, 'accuracy': 91.92}
# Best model yet, saving
# Epoch 45
# Validation metrics:
# {'loss': 0.00027893538936041296, 'accuracy': 91.89}
# Epoch 46
# Validation metrics:
# {'loss': 0.0002736902388278395, 'accuracy': 92.05}
# Epoch 47
# Validation metrics:
# {'loss': 0.00027911964571103454, 'accuracy': 92.0}
# Epoch 48
# Validation metrics:
# {'loss': 0.0002745472884271294, 'accuracy': 91.91}
# Epoch 49
# Validation metrics:
# {'loss': 0.0002745999372564256, 'accuracy': 92.11}
# Epoch 50
# Validation metrics:
# {'loss': 0.0002735181769821793, 'accuracy': 92.12}
# Epoch 51
# Validation metrics:
# {'loss': 0.0002726040838751942, 'accuracy': 92.09}
# Best model yet, saving
# Epoch 52
# Validation metrics:
# {'loss': 0.0002727860992308706, 'accuracy': 92.26}
# Epoch 53
# Validation metrics:
# {'loss': 0.0002755056193564087, 'accuracy': 92.0}
# Epoch 54
# Validation metrics:
# {'loss': 0.0002771568833850324, 'accuracy': 92.04}
# Epoch 55
# Validation metrics:
# {'loss': 0.00027410537586547434, 'accuracy': 92.0}
# Epoch 56
# Validation metrics:
# {'loss': 0.00027365281130187213, 'accuracy': 92.0}
# Epoch 57
# Validation metrics:
# {'loss': 0.00027602692716754973, 'accuracy': 92.08}
# Epoch 58
# Validation metrics:
# {'loss': 0.00027160081663168967, 'accuracy': 92.2}
# Best model yet, saving
# Epoch 59
# Validation metrics:
# {'loss': 0.0002762782387435436, 'accuracy': 91.87}
# Epoch 60
# Validation metrics:
# {'loss': 0.0002730604028329253, 'accuracy': 92.16}
# Epoch 61
# Validation metrics:
# {'loss': 0.0002705190854612738, 'accuracy': 92.1}
# Best model yet, saving
# Epoch 62
# Validation metrics:
# {'loss': 0.0002744314551819116, 'accuracy': 91.96}
# Epoch 63
# Validation metrics:
# {'loss': 0.0002729296393226832, 'accuracy': 92.06}
# Epoch 64
# Validation metrics:
# {'loss': 0.00027189531829208136, 'accuracy': 92.1}
# Epoch 65
# Validation metrics:
# {'loss': 0.00027081152074970305, 'accuracy': 92.22}
# Epoch 66
# Validation metrics:
# {'loss': 0.00026917553623206913, 'accuracy': 92.23}
# Best model yet, saving
# Epoch 67
# Validation metrics:
# {'loss': 0.0002720523625612259, 'accuracy': 92.06}
# Epoch 68
# Validation metrics:
# {'loss': 0.00026863356470130384, 'accuracy': 92.2}
# Best model yet, saving
# Epoch 69
# Validation metrics:
# {'loss': 0.0002694136346690357, 'accuracy': 92.13}
# Epoch 70
# Validation metrics:
# {'loss': 0.0002688317617867142, 'accuracy': 92.35}
# Epoch 71
# Validation metrics:
# {'loss': 0.0002685346989892423, 'accuracy': 92.35}
# Best model yet, saving
# Epoch 72
# Validation metrics:
# {'loss': 0.00026940516545437276, 'accuracy': 92.11}
# Epoch 73
# Validation metrics:
# {'loss': 0.00026752456324175, 'accuracy': 92.2}
# Best model yet, saving
# Epoch 74
# Validation metrics:
# {'loss': 0.00027189039974473417, 'accuracy': 92.02}
# Epoch 75
# Validation metrics:
# {'loss': 0.000269953568931669, 'accuracy': 92.16}
# Epoch 76
# Validation metrics:
# {'loss': 0.0002711692650336772, 'accuracy': 92.16}
# Epoch 77
# Validation metrics:
# {'loss': 0.00026941971736960113, 'accuracy': 92.19}
# Epoch 78
# Validation metrics:
# {'loss': 0.00026918199728243053, 'accuracy': 92.12}
# Epoch 79
# Validation metrics:
# {'loss': 0.0002688580716494471, 'accuracy': 92.25}
# Epoch 80
# Validation metrics:
# {'loss': 0.0002723732322920114, 'accuracy': 92.01}
# Epoch 81
# Validation metrics:
# {'loss': 0.00027246709214523435, 'accuracy': 91.96}
# Epoch 82
# Validation metrics:
# {'loss': 0.00026898685609921813, 'accuracy': 92.17}
# Epoch 83
# Validation metrics:
# {'loss': 0.00026869337307289243, 'accuracy': 92.21}
# Epoch 84
# Validation metrics:
# {'loss': 0.00026843740488402545, 'accuracy': 92.3}
# Epoch 85
# Validation metrics:
# {'loss': 0.0002633963886182755, 'accuracy': 92.38}
# Best model yet, saving
# Epoch 86
# Validation metrics:
# {'loss': 0.00026272854302078485, 'accuracy': 92.48}
# Best model yet, saving
# Epoch 87
# Validation metrics:
# {'loss': 0.00026250153314322233, 'accuracy': 92.44}
# Best model yet, saving
# Epoch 88
# Validation metrics:
# {'loss': 0.0002630776434671134, 'accuracy': 92.4}
# Epoch 89
# Validation metrics:
# {'loss': 0.0002627552312333137, 'accuracy': 92.43}
# Epoch 90
# Validation metrics:
# {'loss': 0.0002628060174174607, 'accuracy': 92.41}
# Epoch 91
# Validation metrics:
# {'loss': 0.0002634213014971465, 'accuracy': 92.42}
# Epoch 92
# Validation metrics:
# {'loss': 0.0002627460053190589, 'accuracy': 92.43}
# Epoch 93
# Validation metrics:
# {'loss': 0.0002627421054057777, 'accuracy': 92.47}
# Epoch 94
# Validation metrics:
# {'loss': 0.0002632199029903859, 'accuracy': 92.37}
# Epoch 95
# Validation metrics:
# {'loss': 0.0002622169558890164, 'accuracy': 92.44}
# Best model yet, saving
# Epoch 96
# Validation metrics:
# {'loss': 0.0002622056636027992, 'accuracy': 92.45}
# Best model yet, saving
# Epoch 97
# Validation metrics:
# {'loss': 0.0002626300847623497, 'accuracy': 92.46}
# Epoch 98
# Validation metrics:
# {'loss': 0.0002624660264700651, 'accuracy': 92.42}
# Epoch 99
# Validation metrics:
# {'loss': 0.00026311702094972134, 'accuracy': 92.39}
# Epoch 100
# Validation metrics:
# {'loss': 0.0002627403591759503, 'accuracy': 92.44}
# Epoch 101
# Validation metrics:
# {'loss': 0.00026259649894200265, 'accuracy': 92.47}
# Epoch 102
# Validation metrics:
# {'loss': 0.0002624150365591049, 'accuracy': 92.43}
# Epoch 103
# Validation metrics:
# {'loss': 0.0002621867461130023, 'accuracy': 92.47}
# Best model yet, saving
# Epoch 104
# Validation metrics:
# {'loss': 0.0002628694346640259, 'accuracy': 92.35}
# Epoch 105
# Validation metrics:
# {'loss': 0.0002629440859891474, 'accuracy': 92.51}
# Epoch 106
# Validation metrics:
# {'loss': 0.0002622555766720325, 'accuracy': 92.41}
# Epoch 107
# Validation metrics:
# {'loss': 0.0002636518038343638, 'accuracy': 92.33}
# Epoch 108
# Validation metrics:
# {'loss': 0.00026315962895751, 'accuracy': 92.44}
# Epoch 109
# Validation metrics:
# {'loss': 0.0002624696062412113, 'accuracy': 92.41}
# Epoch 110
# Validation metrics:
# {'loss': 0.00026220103609375656, 'accuracy': 92.41}
# Epoch 111
# Validation metrics:
# {'loss': 0.00026233692187815905, 'accuracy': 92.54}
# Epoch 112
# Validation metrics:
# {'loss': 0.000262178189586848, 'accuracy': 92.5}
# Best model yet, saving
# Epoch 113
# Validation metrics:
# {'loss': 0.0002623995824251324, 'accuracy': 92.41}
# Epoch 114
# Validation metrics:
# {'loss': 0.00026253648684360087, 'accuracy': 92.35}
# Epoch 115
# Validation metrics:
# {'loss': 0.0002622393658384681, 'accuracy': 92.39}
# Epoch 116
# Validation metrics:
# {'loss': 0.0002622092724777758, 'accuracy': 92.47}
# Epoch 117
# Validation metrics:
# {'loss': 0.00026224530301988125, 'accuracy': 92.43}
# Epoch 118
# Validation metrics:
# {'loss': 0.0002622147439979017, 'accuracy': 92.48}
# Epoch 119
# Validation metrics:
# {'loss': 0.00026224006433039904, 'accuracy': 92.48}
# Epoch 120
# Validation metrics:
# {'loss': 0.0002622246684040874, 'accuracy': 92.5}
# Epoch 121
# Validation metrics:
# {'loss': 0.0002621578751131892, 'accuracy': 92.49}
# Best model yet, saving
# Epoch 122
# Validation metrics:
# {'loss': 0.000262191315414384, 'accuracy': 92.47}
# Epoch 123
# Validation metrics:
# {'loss': 0.0002622024330776185, 'accuracy': 92.48}
# Epoch 124
# Validation metrics:
# {'loss': 0.0002622009487822652, 'accuracy': 92.49}
# Epoch 125
# Validation metrics:
# {'loss': 0.0002621973108034581, 'accuracy': 92.49}
# Epoch 126
# Validation metrics:
# {'loss': 0.0002621471940074116, 'accuracy': 92.47}
# Best model yet, saving
# Epoch 127
# Validation metrics:
# {'loss': 0.00026221893494948745, 'accuracy': 92.48}
# Epoch 128
# Validation metrics:
# {'loss': 0.00026214864919893444, 'accuracy': 92.48}
# Epoch 129
# Validation metrics:
# {'loss': 0.00026214736863039434, 'accuracy': 92.46}
# Epoch 130
# Validation metrics:
# {'loss': 0.00026216846890747547, 'accuracy': 92.45}
# Epoch 131
# Validation metrics:
# {'loss': 0.00026217143749818206, 'accuracy': 92.49}
# Epoch 132
# Validation metrics:
# {'loss': 0.00026220022118650377, 'accuracy': 92.49}
# Epoch 133
# Validation metrics:
# {'loss': 0.0002622032188810408, 'accuracy': 92.49}
# Epoch 134
# Validation metrics:
# {'loss': 0.0002621924795676023, 'accuracy': 92.49}
# Epoch 135
# Validation metrics:
# {'loss': 0.00026218374841846526, 'accuracy': 92.49}
# Epoch 136
# Validation metrics:
# {'loss': 0.0002621814492158592, 'accuracy': 92.49}
# Epoch 137
# Validation metrics:
# {'loss': 0.0002621850580908358, 'accuracy': 92.49}
# Epoch 138
# Validation metrics:
# {'loss': 0.0002621789462864399, 'accuracy': 92.49}
# Epoch 139
# Validation metrics:
# {'loss': 0.00026217749109491706, 'accuracy': 92.49}
# Epoch 140
# Validation metrics:
# {'loss': 0.00026217257254756987, 'accuracy': 92.49}
# Epoch 141
# Validation metrics:
# {'loss': 0.00026216849801130593, 'accuracy': 92.49}
# Epoch 142
# Validation metrics:
# {'loss': 0.00026217009872198105, 'accuracy': 92.49}
# Epoch 143
# Validation metrics:
# {'loss': 0.0002621635503601283, 'accuracy': 92.49}
# Epoch 144
# Validation metrics:
# {'loss': 0.00026216331752948463, 'accuracy': 92.49}
# Epoch 145
# Validation metrics:
# {'loss': 0.00026216343394480646, 'accuracy': 92.49}
# Epoch 146
# Validation metrics:
# {'loss': 0.0002621632884256542, 'accuracy': 92.49}
# Epoch 147
# Validation metrics:
# {'loss': 0.0002621625899337232, 'accuracy': 92.49}
# Early stopping triggered
